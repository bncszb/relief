# %%
import requests

URL="https://regi.kozigazgatas.magyarorszag.hu/onkormanyzatok?selected=Ny"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="hu">
# 	<head>
# 		<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# 		<title>Közigazgatás - Önkormányzatok</title>
# 		<script type='text/javascript' src='/portal-ajax/dyna/prototype.js'></script>
# <script type='text/javascript' src='/portal-ajax/dyna/effects.js'></script>
# <script type='text/javascript' src='/portal-ajax/dyna/dragdrop.js'></script>
# <script type='text/javascript' src='/portal-ajax/dyna/dyna.js'></script>
# <link rel="stylesheet" id="dyna_css" href="/portal-ajax/dyna/style.css" type="text/css"/>
# <script type='text/javascript'>
# server_base_url="/sec/;jsessionid=0DF10C7346B68FBCFBCA6140EA500C69.portal2";
# view_state = "0";
# </script>
#
# 		<link rel="stylesheet" type="text/css" href="/mohu_portlet_frame/themes/kozigazgatas/locals.css" media="screen,projection,print" />
#
# ...
